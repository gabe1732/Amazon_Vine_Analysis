# %%
import pandas as pd
import numpy as np

# %%
# file to load
vine_table_to_load = (r"C:\Users\Vyral\UCFBootcamp\Module_16_Challenge\Challenge\vine_table.csv")

# read data into data frame
vine_table_df = pd.read_csv(vine_table_to_load)

# %%
vine_table_df.head(10)
# Out:
#         review_id  star_rating  helpful_votes  total_votes vine  \
# 0  R3O9SGZBVQBV76            5              0            0    N
# 1   RKH8BNC3L5DLF            5              0            0    N
# 2  R2HLE8WKZSU3NL            2              1            1    N
# 3  R31U3UH5AZ42LL            5              0            0    N
# 4  R2SV659OUJ945Y            4              0            0    N
# 5   RA51CP8TR5A2L            5              0            0    N
# 6   RB2Q7DLDN6TH6            5              1            1    N
# 7  R2RHFJV0UYBK3Y            1              1            5    N
# 8  R2Z6JOQ94LFHEP            5              1            2    N
# 9   RX27XIIWY5JPB            4              0            0    N
#
#   verified_purchase
# 0                 Y
# 1                 Y
# 2                 Y
# 3                 Y
# 4                 Y
# 5                 Y
# 6                 Y
# 7                 N
# 8                 Y
# 9                 Y

# %%
total_votes_df = vine_table_df[vine_table_df.total_votes.gt(20)]
total_votes_df.head()
# Out:
#            review_id  star_rating  helpful_votes  total_votes vine  \
# 619   R1BTWIBLYYVOV7            5             30           30    N
# 1025   R6F9VY91ADPLA            1              8           30    N
# 1548  R3PXNV89DFIXKV            5             35           37    N
# 1573  R2ZF9NYVT3J7D6            5             19           22    N
# 1615  R20NYA5V0UF9NE            5             27           28    N
#
#      verified_purchase
# 619                  Y
# 1025                 N
# 1548                 Y
# 1573                 Y
# 1615                 Y

# %%
total_votes_df["helpful_vote_percent"] = total_votes_df["helpful_votes"] / total_votes_df["total_votes"]
total_votes_df.head()
# Out:
# C:\Users\Vyral\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            review_id  star_rating  helpful_votes  total_votes vine  \
# 619   R1BTWIBLYYVOV7            5             30           30    N
# 1025   R6F9VY91ADPLA            1              8           30    N
# 1548  R3PXNV89DFIXKV            5             35           37    N
# 1573  R2ZF9NYVT3J7D6            5             19           22    N
# 1615  R20NYA5V0UF9NE            5             27           28    N
#
#      verified_purchase  helpful_vote_percent
# 619                  Y              1.000000
# 1025                 N              0.266667
# ...

# %%
helpful_votes_df = total_votes_df[total_votes_df.helpful_vote_percent.gt(.50)]
helpful_votes_df.head()
# Out:
#            review_id  star_rating  helpful_votes  total_votes vine  \
# 619   R1BTWIBLYYVOV7            5             30           30    N
# 1548  R3PXNV89DFIXKV            5             35           37    N
# 1573  R2ZF9NYVT3J7D6            5             19           22    N
# 1615  R20NYA5V0UF9NE            5             27           28    N
# 2304  R2X8FZRUOS8R8C            4             25           26    N
#
#      verified_purchase  helpful_vote_percent
# 619                  Y              1.000000
# 1548                 Y              0.945946
# 1573                 Y              0.863636
# 1615                 Y              0.964286
# 2304                 Y              0.961538

# %%
vine_review_yes_df = vine_table_df[vine_table_df.vine == "Y"]
vine_review_yes_df.head()
# Out:
#            review_id  star_rating  helpful_votes  total_votes vine  \
# 91     R6EMI5RKW73N3            4              1            2    Y
# 178   R3GDHEAHV44OSP            4              0            0    Y
# 228    RJ1N4X4CNQIJ9            4              0            0    Y
# 937    R2IZD1134PGIP            4              1            2    Y
# 1117  R1RVYFAX6ZO2R9            4              0            1    Y
#
#      verified_purchase
# 91                   N
# 178                  N
# 228                  N
# 937                  N
# 1117                 N

# %%
vine_review_no_df = vine_table_df[vine_table_df.vine == "N"]
vine_review_no_df.head()
# Out:
#         review_id  star_rating  helpful_votes  total_votes vine  \
# 0  R3O9SGZBVQBV76            5              0            0    N
# 1   RKH8BNC3L5DLF            5              0            0    N
# 2  R2HLE8WKZSU3NL            2              1            1    N
# 3  R31U3UH5AZ42LL            5              0            0    N
# 4  R2SV659OUJ945Y            4              0            0    N
#
#   verified_purchase
# 0                 Y
# 1                 Y
# 2                 Y
# 3                 Y
# 4                 Y

# %%
summary_vine_review_df["total_reviews"] = vine_table_df.groupby(["star_rating", "vine"]).count()["review_id"]
summary_vine_review_df.head()
# Out:
# star_rating  vine
# 1            N       85142
#              Y          35
# 2            N       51948
#              Y          87
# 3            N       78888
# Name: review_id, dtype: object
